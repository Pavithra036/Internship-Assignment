# %% [markdown]
# ### NumPy Speed Test

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\pavithra h r\anaconda3\lib\site-packages (1.23.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
import numpy as np

# Create 1 million numbers
size = 1_000_000

# Python list
py_list = list(range(size))

# NumPy array
np_array = np.arange(size)

# ---- Python List Operation ----
start = time.time()
py_result = [x * 2 for x in py_list]
end = time.time()

py_time = end - start

# ---- NumPy Array Operation ----
start = time.time()
np_result = np_array * 2
end = time.time()

np_time = end - start

# ---- Results ----
print("Python List Time:", py_time)
print("NumPy Array Time:", np_time)
# Out:
# Python List Time: 0.1391303539276123
# NumPy Array Time: 0.002992391586303711
