# %% [markdown]
# ## Mini Project Proposal

# %% [markdown]
# ### Student Performance Prediction System

# %%
# Problem Statement:
'''
Many students struggle to understand how their study habits affect their academic performance.
This project aims to predict student marks based on factors like study hours, attendance, and previous scores.

'''

# %%
# Dataset:
'''
Type: Student dataset (can be self-created or CSV)

Features:
-Study Hours
-Attendance
-Previous Marks

Label:
-Final Marks / Grade
'''

# %%
# Algorithm Used:
'''
Linear Regression
--> Because it predicts continuous values (marks) based on input features

'''

# %%
# Methodology:
'''
1.Collect or create dataset
2.Clean and preprocess data
3.Train Linear Regression model
4.Test with new input
5.Evaluate predictions

'''

# %%
# Expected Output:
'''
Predicted marks based on input values
Insight into how study habits affect performance

'''
