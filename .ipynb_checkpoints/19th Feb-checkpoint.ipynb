# %% [markdown]
# ### Student Data Manager

# %%
# Storing data for 5 students
students = []

for i in range(5):
    print(f"\nEnter details for Student {i+1}")
    name = input("Name: ")
    marks = float(input("Marks: "))

    student = {
        "name": name,
        "marks": marks
    }
    students.append(student)

# Finding topper
topper = students[0]
total_marks = 0

for student in students:
    total_marks += student["marks"]
    if student["marks"] > topper["marks"]:
        topper = student

# Calculating class average
average = total_marks / len(students)

# Function to assign grade
def assign_grade(marks):
    if marks >= 90:
        return "A"
    elif marks >= 75:
        return "B"
    elif marks >= 50:
        return "C"
    else:
        return "F"

# Printing results
print("\n--- Student Grades ---")
for student in students:
    grade = assign_grade(student["marks"])
    print(f"{student['name']} - Marks: {student['marks']} - Grade: {grade}")

print("\n--- Summary ---")
print(f"Topper: {topper['name']} with {topper['marks']} marks")
print(f"Class Average: {average:.2f}")
# Out:
# Enter details for Student 1
# Name: alice
# Marks: 80
#
# Enter details for Student 2
# Name: bob
# Marks: 75
#
# Enter details for Student 3
# Name: carry
# Marks: 82
#
# Enter details for Student 4
# Name: anav
# Marks: 86
#
# Enter details for Student 5
# Name: ajay
# Marks: 83
#
# --- Student Grades ---
# alice - Marks: 80.0 - Grade: B
# bob - Marks: 75.0 - Grade: B
# carry - Marks: 82.0 - Grade: B
# anav - Marks: 86.0 - Grade: B
# ajay - Marks: 83.0 - Grade: B
#
# --- Summary ---
# Topper: anav with 86.0 marks
# Class Average: 81.20
