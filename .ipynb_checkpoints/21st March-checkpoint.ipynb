# %% [markdown]
# ### Build a Text Cleaner

# %%
import string
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# %%
# Text Cleaning Function ----
def clean_text(text):
    # 1. Lowercase
    text = text.lower()
    
    # 2. Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # 3. Remove stopwords
    words = text.split()
    cleaned_words = [word for word in words if word not in ENGLISH_STOP_WORDS]
    
    return " ".join(cleaned_words)

# %%
# Test the function ----
sample_text = "Hello!!! This is a sample sentence, and it is very useful."

cleaned = clean_text(sample_text)

print("Original Text:")
print(sample_text)

print("\nCleaned Text:")
print(cleaned)
# Out:
# Original Text:
# Hello!!! This is a sample sentence, and it is very useful.
#
# Cleaned Text:
# hello sample sentence useful
