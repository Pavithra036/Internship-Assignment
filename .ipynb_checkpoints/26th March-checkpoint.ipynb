# %% [markdown]
# ### Movie Review Analyzer

# %%
pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.19.0-py3-none-any.whl (624 kB)
#      -------------------------------------- 624.3/624.3 kB 1.0 MB/s eta 0:00:00
# Collecting nltk>=3.9
#   Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: click in c:\users\pavithra h r\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.0.4)
# Requirement already satisfied: tqdm in c:\users\pavithra h r\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pavithra h r\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2022.7.9)
# Requirement already satisfied: joblib in c:\users\pavithra h r\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: colorama in c:\users\pavithra h r\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.5)
# Installing collected packages: nltk, textblob
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# Successfully installed nltk-3.9.2 textblob-0.19.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

# %%
# 1. Sample Reviews ----
reviews = [
    "This movie was amazing and fantastic!",
    "I really liked the story and acting",
    "The movie was okay, not great",
    "I did not like the movie, it was boring",
    "Worst movie ever, waste of time"
]

# %%
# 2. Analyze Sentiment ----
for review in reviews:
    blob = TextBlob(review)
    polarity = blob.sentiment.polarity

    if polarity > 0:
        sentiment = "Positive"
    elif polarity == 0:
        sentiment = "Neutral"
    else:
        sentiment = "Negative"

    print(f"Review: {review}")
    print(f"Sentiment: {sentiment}\n")
# Out:
# Review: This movie was amazing and fantastic!
# Sentiment: Positive
#
# Review: I really liked the story and acting
# Sentiment: Positive
#
# Review: The movie was okay, not great
# Sentiment: Positive
#
# Review: I did not like the movie, it was boring
# Sentiment: Negative
#
# Review: Worst movie ever, waste of time
# Sentiment: Negative
