# %% [markdown]
# # ML Idea Generator

# %% [markdown]
# ### 1. College Domain – Student Performance Prediction
# #### Problem: Predict student marks/performance
# #### Input: Attendance, study hours, previous marks
# #### Output: Predicted score / grade

# %% [markdown]
# ### 2. Healthcare – Disease Prediction System
# #### Problem: Predict possible disease based on symptoms
# #### Input: Symptoms, age, medical history
# #### Output: Disease prediction (e.g., diabetes, flu)

# %% [markdown]
# ### 3. Shopping – Product Recommendation System
# #### Problem: Recommend products to users
# #### Input: User purchase history, browsing behavior
# #### Output: Suggested products

# %% [markdown]
# ### 4. College – Placement Prediction
# #### Problem: Predict whether a student will get placed
# #### Input: CGPA, skills, projects, internships
# #### Output: Placed / Not Placed

# %% [markdown]
# ### 5. Healthcare – Appointment No-Show Prediction
# #### Problem: Predict if a patient will miss appointment
# #### Input: Past attendance, age, booking details
# #### Output: Show / No-show

# %% [markdown]
# ### 6. Shopping – Price Prediction
# #### Problem: Predict product price
# #### Input: Brand, category, features
# #### Output: Estimated price
